# %% [markdown]
# # Opus-MT Translation

# %% [markdown]
# Opus-MT is a set of translation models developed by Helsinki-NLP (Language Technology at the University of Helsinki), you can easily use these models with Hugging Face, therefore we're going to need to install transformers and TensorFlow.

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\javi\anaconda3\lib\site-packages (4.20.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in c:\users\javi\anaconda3\lib\site-packages (from transformers) (0.12.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\javi\anaconda3\lib\site-packages (from transformers) (2021.4.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in c:\users\javi\anaconda3\lib\site-packages (from transformers) (0.8.1)
# Requirement already satisfied: filelock in c:\users\javi\anaconda3\lib\site-packages (from transformers) (3.0.12)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\javi\anaconda3\lib\site-packages (from transformers) (5.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\javi\anaconda3\lib\site-packages (from transformers) (20.9)
# Requirement already satisfied: tqdm>=4.27 in c:\users\javi\anaconda3\lib\site-packages (from transformers) (4.64.0)
# Requirement already satisfied: requests in c:\users\javi\anaconda3\lib\site-packages (from transformers) (2.25.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\javi\anaconda3\lib\site-packages (from transformers) (1.20.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\javi\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\javi\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: colorama in c:\users\javi\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\javi\anaconda3\lib\site-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\javi\anaconda3\lib\site-packages (from requests->transformers) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\javi\anaconda3\lib\site-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\javi\anaconda3\lib\site-packages (from requests->transformers) (2.10)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\javi\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (1.20.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: setuptools in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (52.0.0.post20210125)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (1.47.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: packaging in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (20.9)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (2.9.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\javi\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\javi\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.36.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\javi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\javi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\javi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\javi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.9.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\javi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.3.7)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\javi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\javi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.25.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\javi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\javi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\javi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\javi\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\javi\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\javi\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.4.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\javi\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\javi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\javi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\javi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\javi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\javi\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\javi\anaconda3\lib\site-packages (from packaging->tensorflow) (2.4.7)

# %% [markdown]
# Now we will create a simple function to translate a string. The model we're going to work with is "Helsinki-NLP/opus-mt-en-es", we are going to set this model as a global var for convenience.

# %%
from transformers import pipeline

# %%
translator = pipeline("translation", model="Helsinki-NLP/opus-mt-en-es")
translator("Default to expanded threads")
# Out:
# [{'translation_text': 'Predeterminado a los hilos de discusión expandidos'}]

# %% [markdown]
# The following method will filter the english question from the questions list and use the translator to generate a new quesiton list that includes the spanish question.

# %%
def translate_question_to_spanish(question, id):
    try:
        en_question = next(filter((lambda x: x.get("language") == "en"), question))
        translation = translator(en_question.get("string"))[0].get('translation_text')
        question.append({"language": "es", "question" : translation})
    except StopIteration:
        print("No english version was found for the question ", id)
    except:
        print("Unexpected Error")
    finally:
        return question
def generate_new_question(question):
    question['question'] = translate_question_to_spanish(question.get('question'), question.get('id'))
    return question
    
def translate_questions(questions):
    questions['questions'] = list(map(generate_new_question, questions.get('questions')))
    return questions

# %% [markdown]
# Now let's import the files to generate a spanish version of all the question

# %%
import json

# %%
def read_json(filename):
    with open(filename, 'r', encoding="utf8") as f:
        return json.load(f)

# %%
test_dbpedia = read_json("../data/qald_9_plus_test_dbpedia.json")
train_dbpedia = read_json("../data/qald_9_plus_train_dbpedia.json")
test_wikidata = read_json("../data/qald_9_plus_test_wikidata.json")
train_wikidata = read_json("../data/qald_9_plus_train_wikidata.json")

# %% [markdown]
# Let's check if everythin is OK by using DBpedia test data

# %%
test_dbpedia = translate_questions(test_dbpedia)

# %%
test_dbpedia
# Out:
# {'questions': [{'id': '99',
#    'question': [{'language': 'en',
#      'string': 'What is the time zone of Salt Lake City?'},
#     {'language': 'de', 'string': 'In welcher Zeitzone liegt Salt Lake City?'},
#     {'language': 'de', 'string': 'Was ist die Zeitzone von Salt Lake City?'},
#     {'language': 'ru', 'string': 'Какой часовой пояс в Солт-Лейк-Сити'},
#     {'language': 'ru',
#      'string': 'В каком часовом поясе расположен Солт-Лейк-Сити?'},
#     {'language': 'uk', 'string': 'Який часовий пояс у Солт-Лейк Сіті?'},
#     {'language': 'lt', 'string': 'Kokia Solt Leik Sičio laiko zona?'},
#     {'language': 'be', 'string': 'Які гадзінны пояс у Солт-Лэйк-Сіці'},
#     {'language': 'lt', 'string': 'Kokia laiko juosta yra Solt Leik Sityjes'},
#     {'language': 'ba', 'string': 'Ниндей вакыт поясы Солт-Лейк-Ситила'},
#     {'language': 'es',
#      'question': '¿Cuál es la zona horaria de Salt Lake City?'}],
#    'query': {'sparql': 'PREFIX res: <http://dbpedia.org/resource/> PREFIX dbp: <http://dbpedia.org/property/> SELECT DISTINCT ?uri WHERE { res:Salt_Lake_City <http://dbpedia.org/ontology/timeZone> ?uri }'},
#    'answers': [{'head': {'link': [], 'vars': ['uri']},
#      'results': {'bindings': [{'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Mountain_Time_Zone'}}]}}]},
#   {'id': '98',
#    'question': [{'language': 'en', 'string': 'Who killed Caesar?'},
#     {'language': 'de', 'string': 'Wer hat Caesar ermordet?'},
#     {'language': 'de', 'string': 'Wer hat Cäsar getötet?'},
#     {'language': 'ru', 'string': 'Кто убил Цезаря'},
#     {'language': 'uk', 'string': 'Хто вбив Цезаря?'},
#     {'language': 'lt', 'string': 'Kas nužudė Cezarį?'},
#     {'language': 'be', 'string': 'Хто забіў Цэзара'},
#     {'language': 'ba', 'string': 'Кем Цезарьзы ултергэн?'},
#     {'language': 'es', 'question': '¿Quién mató a César?'}],
#    'query': {'sparql': 'PREFIX dct: <http://purl.org/dc/terms/> PREFIX dbc: <http://dbpedia.org/resource/Category:> SELECT DISTINCT ?uri WHERE { ?uri dct:subject dbc:Assassins_of_Julius_Caesar }'},
#    'answers': [{'head': {'link': [], 'vars': ['uri']},
#      'results': {'bindings': [{'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Tillius_Cimber'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Quintus_Antistius_Labeo'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Gaius_Cassius_Parmensis'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Gaius_Servilius_Casca'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Gaius_Trebonius'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Marcus_Porcius_Cato_(son_of_Cato_the_Younger)'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Publius_Servilius_Casca'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Lucius_Minucius_Basilus'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Gaius_Cassius_Longinus'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Marcus_Junius_Brutus'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Pontius_Aquila'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Decimus_Junius_Brutus_Albinus'}}]}}]},
#   {'id': '86',
#    'question': [{'language': 'en',
#      'string': 'What is the highest mountain in Germany?'},
#     {'language': 'de', 'string': 'Wie heißt der höchste Berg in Deutschland?'},
#     {'language': 'ru', 'string': 'Самая высокая гора в Германии?'},
#     {'language': 'ru', 'string': 'Самая высокая гора Германии?'},
#     {'language': 'ru', 'string': 'Какая гора самая высокая в Германии?'},
#     {'language': 'ru',
#      'string': 'Какая гора является самой высокой в Германии?'},
#     {'language': 'uk', 'string': 'Найвища гора в Німеччині?'},
#     {'language': 'uk', 'string': 'Яка найвища гора у Німеччині?'},
#     {'language': 'be', 'string': 'Самая высокая гара ў Германіі?'},
#     {'language': 'lt', 'string': 'Pats Aukščiausias kalnas Vokietijoje?'},
#     {'language': 'lt', 'string': 'Aukščiausias kalnas Vokietijoje?'},
#     {'language': 'ba', 'string': 'Германияла иң бейек тау?'},
#     {'language': 'es',
#      'question': '¿Cuál es la montaña más alta de Alemania?'}],
#    'query': {'sparql': 'PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> PREFIX onto: <http://dbpedia.org/ontology/> SELECT ?uri WHERE { ?uri rdf:type onto:Mountain ; onto:elevation ?elevation ; onto:locatedInArea <http://dbpedia.org/resource/Germany> } ORDER BY DESC(?elevation) LIMIT 1'},
#    'answers': [{'head': {'link': [], 'vars': ['uri']},
#      'results': {'bindings': [{'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Zugspitze'}}]}}]},
#   {'id': '84',
#    'question': [{'language': 'en',
#      'string': 'Which American presidents were in office during the Vietnam War?'},
#     {'language': 'de',
#      'string': 'Welche amerikanischen Präsidenten waren während des Vietnamkrieges im Amt?'},
#     {'language': 'ru',
#      'string': 'Американский президент, который был во время войны во Вьетнаме?'},
#     {'language': 'ru',
#      'string': 'Кто был американским президентом во время войны во Вьетнаме?'},
#     {'language': 'ru',
#      'string': 'Какие американские президенты находились у власти во время войны во Вьетнаме?'},
#     {'language': 'ru',
#      'string': 'Каких американских президентов застала война во Вьетнаме?'},
#     {'language': 'uk',
#      'string': "Який американський президент правив під час війни у В'єтнамі?"},
#     {'language': 'uk',
#      'string': "Які американські президенти були на посаді під час війни у В'єтнамі?"},
#     {'language': 'be',
#      'string': "Амерыканскі прэзідэнт, які быў падчас вайны ў В'етнаме?"},
#     {'language': 'ba',
#      'string': 'Ниндей американский президент икенсе хугыш булган вакытта Вьетнамда?'},
#     {'language': 'es',
#      'question': '¿Qué presidentes estadounidenses estuvieron en el cargo durante la guerra de Vietnam?'}],
#    'query': {'sparql': 'PREFIX dbo: <http://dbpedia.org/ontology/> PREFIX res: <http://dbpedia.org/resource/> PREFIX dct: <http://purl.org/dc/terms/> PREFIX dbc: <http://dbpedia.org/resource/Category:> SELECT ?uri WHERE { ?uri dct:subject dbc:Presidents_of_the_United_States . res:Vietnam_War dbo:commander ?uri }'},
#    'answers': [{'head': {'link': [], 'vars': ['uri']},
#      'results': {'bindings': [{'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Lyndon_B._Johnson'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/John_F._Kennedy'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Richard_Nixon'}}]}}]},
#   {'id': '81',
#    'question': [{'language': 'en',
#      'string': 'Butch Otter is the governor of which U.S. state?'},
#     {'language': 'de',
#      'string': 'Butch Otter ist der Gouverneur welches US-Staates?'},
#     {'language': 'ru',
#      'string': 'Губернатором какого штата является Бутч Оттер?'},
#     {'language': 'ru',
#      'string': 'Губернатором какого штата США является Бутч Оттер?'},
#     {'language': 'uk', 'string': 'Губернатором якого штату є Бутч Оттер?'},
#     {'language': 'uk',
#      'string': 'Губернатором якого американського штату був Бутч Оттер?'},
#     {'language': 'be',
#      'string': "Губернатарам якога штата з'яўляецца Бутч Оттэр?"},
#     {'language': 'lt',
#      'string': 'Kurios valstijos gubernatorius yra Butchas Otteris?'},
#     {'language': 'ba',
#      'string': 'Штат губернаторы, бусины оттирать ниндәй була?'},
#     {'language': 'ba', 'string': 'Штат губернаторы, Бутч Оттер ниндәй була?'},
#     {'language': 'es',
#      'question': 'Butch Otter es el gobernador de qué estado de los EE.UU.?'}],
#    'query': {'sparql': 'SELECT DISTINCT ?uri WHERE { ?uri a <http://dbpedia.org/class/yago/WikicatStatesOfTheUnitedStates> ; <http://dbpedia.org/property/governor> <http://dbpedia.org/resource/Butch_Otter> }'},
#    'answers': [{'head': {'link': [], 'vars': ['uri']},
#      'results': {'bindings': []}}]},
#   {'id': '73',
#    'question': [{'language': 'en',
#      'string': 'How many gold medals did Michael Phelps win at the 2008 Olympics?'},
#     {'language': 'de',
#      'string': 'Wie viele Goldmedaillen hat Michael Phelbs bei den Olympischen Spielen 2008 gewonnen?'},
#     {'language': 'ru',
#      'string': 'Сколько золотых медалей выиграл Михаэль Фелпс на Олимпийских играх в 2008 году?'},
#     {'language': 'ru',
#      'string': 'Сколько золотых медалей завоевал Майкл Фелпс в Олимпийских играх в 2008 года?'},
#     {'language': 'ru',
#      'string': 'Сколько золотых медалей выиграл Майкл Фэлпс на Олимпиаде 2008?'},
#     {'language': 'ru',
#      'string': 'Сколько золотых медалей выйграл Майкл Фелпс в Олимпиаде-2008?'},
#     {'language': 'uk',
#      'string': 'Скільки золотих медалей виграв Міхаель Фелпс на Олімпійских іграх 2008 року?'},
#     {'language': 'uk',
#      'string': 'Скільки золотих медалей виграв Майкл Фелпс на Олімпіаді 2008 року?'},
#     {'language': 'be',
#      'string': 'Колькі залатых медалёў выйграў Міхаэль Фелпс на Алімпійскіх гульнях у 2008 годзе?'},
#     {'language': 'lt',
#      'string': 'Kiek aukso medalių Michaelas Phelpsas iškovojo 2008 m. olimpinėse žaidynėse?'},
#     {'language': 'ba',
#      'string': 'Михаэль олимпия уйындарында алтын миҙал яулаусы 2008 йыл фелпс ни?'},
#     {'language': 'ba',
#      'string': 'Михаэль Фелпс олимпия уйындарында алтын миҙал 2008 йылда ниндәй яулаусы?'},
#     {'language': 'es',
#      'question': '¿Cuántas medallas de oro ganó Michael Phelps en las Olimpiadas de 2008?'}],
#    'query': {'sparql': 'PREFIX dbo: <http://dbpedia.org/ontology/> PREFIX dbr: <http://dbpedia.org/resource/> PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> SELECT Count(?sub) as ?c WHERE { ?sub dbo:goldMedalist dbr:Michael_Phelps . filter (contains (str(?sub), "2008") && contains (str(?sub), "Olympics")) }'},
#    'answers': [{'head': {'link': [], 'vars': ['c']},
#      'results': {'bindings': [{'c': {'type': 'typed-literal',
#          'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#          'value': '8'}}]}}]},
#   {'id': '66',
#    'question': [{'language': 'en',
#      'string': 'Which artists were born on the same date as Rachel Stevens?'},
#     {'language': 'de',
#      'string': 'Welche Künstler sind am gleichen Tag wie Rachel Stevens geboren?'},
#     {'language': 'ru',
#      'string': 'Какие актеры родились в тоже день с Рэйчел Стивенс?'},
#     {'language': 'ru',
#      'string': 'Какие художники родились в один день с Рэйчел Стивенс?'},
#     {'language': 'ru',
#      'string': 'Какие артисты родились в тот же день, что и Рейчел Стивенс?'},
#     {'language': 'ru',
#      'string': 'Кто из артистов родился в один день с Рэйчел Стивенс?'},
#     {'language': 'uk',
#      'string': 'Які актори народились в один день з Рейчел Стівенс?'},
#     {'language': 'uk',
#      'string': 'Які художники народилися того ж самого дня, що і Рейчел Стівенс?'},
#     {'language': 'be',
#      'string': 'Якія акцёры нарадзіліся ў адзiн дзень з Рэйчэл Стывенс?'},
#     {'language': 'lt',
#      'string': 'Kurie aktoriai gimė tą pačią dieną kaip Rachel Stevens?'},
#     {'language': 'ba',
#      'string': 'Тыуған көнөң менән рейчел стивенс актер ҙа ниндәй?'},
#     {'language': 'es',
#      'question': '¿Qué artistas nacieron en la misma fecha que Rachel Stevens?'}],
#    'query': {'sparql': 'PREFIX dbo: <http://dbpedia.org/ontology/> PREFIX dbr: <http://dbpedia.org/resource/> SELECT DISTINCT ?uri WHERE { ?uri a dbo:Artist . dbr:Rachel_Stevens dbo:birthDate ?birthdate . ?uri dbo:birthDate ?birthdate }'},
#    'answers': [{'head': {'link': [], 'vars': ['uri']},
#      'results': {'bindings': [{'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Cameron_Cartio'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Vesna_Pisarović'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Gizem_Saka'}}]}}]},
#   {'id': '64',
#    'question': [{'language': 'en',
#      'string': 'What is the profession of Frank Herbert?'},
#     {'language': 'de', 'string': 'Welchen Beruf hat Frank Herbert?'},
#     {'language': 'ru', 'string': 'Професия Френка Герберта?'},
#     {'language': 'ru', 'string': 'Какая профессия у Фрэнка Герберта?'},
#     {'language': 'ru', 'string': 'Какая профессия у Франка Герберта?'},
#     {'language': 'ru', 'string': 'Кем является Франк Герберт?'},
#     {'language': 'uk', 'string': 'Професія Френка Герберта?'},
#     {'language': 'uk', 'string': 'Яка професія Френка Герберта?'},
#     {'language': 'be', 'string': 'Прафесія Фрэнка Герберта? '},
#     {'language': 'lt', 'string': 'Franko Herberto profesija?'},
#     {'language': 'ba', 'string': 'Фрэнк Һөнәри Герберт?'},
#     {'language': 'ba', 'string': 'Герберт Френк професия ниндәй?'},
#     {'language': 'es', 'question': '¿Cuál es la profesión de Frank Herbert?'}],
#    'query': {'sparql': 'PREFIX dbpedia2: <http://dbpedia.org/property/> PREFIX res: <http://dbpedia.org/resource/> SELECT DISTINCT ?string WHERE { res:Frank_Herbert dbpedia2:occupation ?string }'},
#    'answers': [{'head': {'link': [], 'vars': ['string']},
#      'results': {'bindings': [{'string': {'type': 'literal',
#          'xml:lang': 'en',
#          'value': 'Novelist'}}]}}]},
#   {'id': '6',
#    'question': [{'language': 'en',
#      'string': 'Are Taiko some kind of Japanese musical instrument?'},
#     {'language': 'de',
#      'string': 'Sind Taiko eine Art von japanischen Musikinstrument?'},
#     {'language': 'ru',
#      'string': 'Является ли Тайко японским музыкальным инструментом?'},
#     {'language': 'ru',
#      'string': 'Таико это некий японский музыкальный инструмент?'},
#     {'language': 'uk',
#      'string': 'Чи є Тайко японським музичним інструментом?'},
#     {'language': 'uk',
#      'string': 'Чи тайко є різновидом японського музичного інструменту?'},
#     {'language': 'be',
#      'string': "Ці з'яўляецца Тайко японскім музычным інструментам?"},
#     {'language': 'lt', 'string': 'Taiko yra japonų muzikos instrumentas?'},
#     {'language': 'ba', 'string': 'Тайко япон музыка ҡоралы булып бармы?'},
#     {'language': 'es',
#      'question': '¿Taiko es algún tipo de instrumento musical japonés?'}],
#    'query': {'sparql': 'ASK WHERE { <http://dbpedia.org/resource/Taiko> a <http://dbpedia.org/class/yago/WikicatJapaneseMusicalInstruments> }'},
#    'answers': [{'head': {'link': []}, 'boolean': True}]},
#   {'id': '56',
#    'question': [{'language': 'en',
#      'string': 'How many seats does the home stadium of FC Porto have?'},
#     {'language': 'de',
#      'string': 'Wie viele Sitzplätze hat das Heimstadion vom FC Porto?'},
#     {'language': 'ru',
#      'string': 'Сколько мест на домашенм стадионе футбольного клуба Порту?'},
#     {'language': 'ru',
#      'string': 'Сколько мест на домашнем стадионе FC Porto?'},
#     {'language': 'ru',
#      'string': 'Какая вместимость у домашнего стадиона ФК Порту?'},
#     {'language': 'ru',
#      'string': 'Какая вместимость стадиона футбольного клуба Порто?'},
#     {'language': 'uk',
#      'string': 'Скільки місць на домашньому стадіоні футбольного клубу Порту?'},
#     {'language': 'uk',
#      'string': 'Скільки вміщує домашній стадіон футбольного клубу Порту?'},
#     {'language': 'be',
#      'string': 'Колькі месцаў на дамашнім стадыёне футбольнага клуба Порту?'},
#     {'language': 'lt', 'string': 'Kiek vietų yra FC Porto stadione?'},
#     {'language': 'ba',
#      'string': 'Порт стадионында футбол клубы өй урындар күпме?'},
#     {'language': 'es',
#      'question': '¿Cuántos asientos tiene el estadio del FC Porto?'}],
#    'query': {'sparql': 'PREFIX dbo: <http://dbpedia.org/ontology/> PREFIX dbp: <http://dbpedia.org/property/> PREFIX dbr: <http://dbpedia.org/resource/> PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> PREFIX db: <http://dbpedia.org/> SELECT ?capacity WHERE { { dbr:FC_Porto dbo:ground ?ground . ?ground dbo:capacity ?capacity } UNION { dbr:FC_Porto dbo:ground ?ground . ?ground dbp:capacity ?capacity } }'},
#    'answers': [{'head': {'link': [], 'vars': ['capacity']},
#      'results': {'bindings': [{'capacity': {'type': 'typed-literal',
#          'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#          'value': '50035'}}]}}]},
#   {'id': '49',
#    'question': [{'language': 'en',
#      'string': 'Which frequent flyer program has the most airlines?'},
#     {'language': 'de',
#      'string': 'Welches Vielfliegerprogramm hat die meisten Fluglinien?'},
#     {'language': 'ru',
#      'string': 'В какой программе для часто летающих пасажиров больше всего авиакомпаний?'},
#     {'language': 'ru',
#      'string': 'Какая бонусная программа для часто летающих пассажировк включает большее число авиакомпаний?'},
#     {'language': 'ru',
#      'string': 'В какой распространённой программе для авиапассажиров больше всего авиалиний?'},
#     {'language': 'ru',
#      'string': 'Какая бонусная программа есть у большинства авиакомпаний?'},
#     {'language': 'uk',
#      'string': 'У якій програмі для часто літаючих пасажирів найбільше компаній?'},
#     {'language': 'uk',
#      'string': 'Яку бонусну програму мають більшість авіакомпаній?'},
#     {'language': 'be',
#      'string': 'У якой праграме для пасажыраў, якія часта лятаюць, больш за ўсё авіякампаній?'},
#     {'language': 'lt',
#      'string': 'Kurioje nuolatinių skrydžių programoje yra daugiausia oro linijų?'},
#     {'language': 'es',
#      'question': '¿Qué programa de viajero frecuente tiene la mayoría de las aerolíneas?'}],
#    'query': {'sparql': 'SELECT ?uri WHERE { ?airline <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/Airline> . ?airline <http://dbpedia.org/property/frequentFlyer> ?uri. } GROUP BY ?uri ORDER BY DESC(COUNT(DISTINCT ?airline)) OFFSET 0 LIMIT 1'},
#    'answers': [{'head': {'link': [], 'vars': ['uri']},
#      'results': {'bindings': [{'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Miles_&_More'}}]}}]},
#   {'id': '44',
#    'question': [{'language': 'en',
#      'string': 'Which European countries have a constitutional monarchy?'},
#     {'language': 'de',
#      'string': 'Welche europäischen Länder haben eine parlamentarische Monarchie?'},
#     {'language': 'ru',
#      'string': 'В какой европейской стране конституционная монархия?'},
#     {'language': 'ru',
#      'string': 'Какие европейские страны являются конституционными монархиями?'},
#     {'language': 'ru',
#      'string': 'Какие европейские страны имеют конституционную монархию?'},
#     {'language': 'ru',
#      'string': 'В каких европейских страна установлена конституционная монархия?'},
#     {'language': 'uk',
#      'string': 'Яка європейска карїна має конституційну монархію?'},
#     {'language': 'uk',
#      'string': 'Які європейські країни мають конституційну монархію?'},
#     {'language': 'be',
#      'string': 'У якой еўрапейскай краіне канстытуцыйная манархія?'},
#     {'language': 'es',
#      'question': '¿Qué países europeos tienen una monarquía constitucional?'}],
#    'query': {'sparql': 'PREFIX dbo: <http://dbpedia.org/ontology/> PREFIX dct: <http://purl.org/dc/terms/> PREFIX dbc: <http://dbpedia.org/resource/Category:> PREFIX dbr: <http://dbpedia.org/resource/> SELECT ?uri WHERE { ?uri dct:subject dbc:Countries_in_Europe ; dbo:governmentType dbr:Constitutional_monarchy }'},
#    'answers': [{'head': {'link': [], 'vars': ['uri']},
#      'results': {'bindings': [{'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Belgium'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Denmark'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/United_Kingdom'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Sweden'}}]}}]},
#   {'id': '42',
#    'question': [{'language': 'en',
#      'string': 'Which countries have places with more than two caves?'},
#     {'language': 'de',
#      'string': 'Welche Länder haben Orte mit mehr als zwei Höhlen?'},
#     {'language': 'ru',
#      'string': 'В каких странах есть места с более чем двумя пещерами?'},
#     {'language': 'ru',
#      'string': 'В каких странах есть, имеющие более двух пещер?'},
#     {'language': 'uk',
#      'string': 'Які країни мають місця з більш ніж двома печерами?'},
#     {'language': 'be',
#      'string': 'У якiх краiнах ёсць месцы з больш чым дзвюма пячорамi?'},
#     {'language': 'uk',
#      'string': 'В яких країнах є місця з більш ніж двома печерами '},
#     {'language': 'uk',
#      'string': 'У яких країнах є місця з більш ніж двома печерами'},
#     {'language': 'be',
#      'string': 'У якіх краінах ёсць месцы з больш чым двума пячорамі'},
#     {'language': 'lt',
#      'string': 'Kuriose šalyse yra daugiau nei dviejų urvų?'},
#     {'language': 'lt',
#      'string': 'Kuriose šalyse yra vietų, kuriose yra daugiau nei du urvai'},
#     {'language': 'ba',
#      'string': 'Ҡайһы илдәрҙә ике мәмерйәнән дә күберәк урындар бар?'},
#     {'language': 'es',
#      'question': '¿Qué países tienen lugares con más de dos cuevas?'}],
#    'query': {'sparql': 'PREFIX dbo: <http://dbpedia.org/ontology/> PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> SELECT DISTINCT ?uri WHERE { ?cave rdf:type dbo:Cave ; dbo:location ?uri . ?uri rdf:type dbo:Country } GROUP BY ?uri HAVING ( COUNT(?cave) > 2 )'},
#    'answers': [{'head': {'link': [], 'vars': ['uri']},
#      'results': {'bindings': [{'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Germany'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Venezuela'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Cumbria'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Japan'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Republic_of_Ireland'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Taiwan'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Western_Australia'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/China'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Spain'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/India'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Canada'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Serbia'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Abkhazia'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Derbyshire'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Gibraltar'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Slovakia'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Lancashire'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/United_Kingdom'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Brazil'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Somerset'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/South_Africa'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Russia'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/British_Columbia'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Mexico'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Austria'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Philippines'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Northern_Territory'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Georgia_(country)'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Jamaica'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Australia'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/England'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Israel'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Romania'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Devon'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Vietnam'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Slovenia'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/North_Yorkshire'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Turkey'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/France'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Greece'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/United_States'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Bosnia_and_Herzegovina'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Italy'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Wales'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Portugal'}}]}}]},
#   {'id': '4',
#    'question': [{'language': 'en',
#      'string': 'Which airports are located in California, USA?'},
#     {'language': 'de',
#      'string': 'Welche Flughäfen gibt es in Kalifornien, USA?'},
#     {'language': 'ru',
#      'string': 'Какие аэропорты расположены в штате США Калифорнии?'},
#     {'language': 'ru',
#      'string': 'Какие аэропорты находятся в Калифорнии (США)?'},
#     {'language': 'uk',
#      'string': 'Які аеропорти знаходяться в Калфорнії, США?'},
#     {'language': 'be',
#      'string': 'Якiя аэрапорты знаходзяцца ў Калiфорнii, ЗША?'},
#     {'language': 'lt',
#      'string': 'Kokie oro uostai yra JAV Kalifornijos valstijoje?'},
#     {'language': 'es',
#      'question': '¿Qué aeropuertos se encuentran en California, EE.UU.?'}],
#    'query': {'sparql': 'SELECT DISTINCT ?uri WHERE { ?uri a <http://dbpedia.org/ontology/Airport> { ?uri <http://dbpedia.org/ontology/location> <http://dbpedia.org/resource/California> } UNION { ?uri <http://dbpedia.org/ontology/city> <http://dbpedia.org/resource/California> } UNION { ?uri <http://dbpedia.org/ontology/city> ?city . ?city <http://dbpedia.org/ontology/isPartOf> <http://dbpedia.org/resource/California> } UNION { ?uri <http://dbpedia.org/ontology/operator> <http://dbpedia.org/resource/California> } }'},
#    'answers': [{'head': {'link': [], 'vars': ['uri']},
#      'results': {'bindings': [{'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/California_Pines_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Camp_Dunlap'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Hayfork_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Healdsburg_Municipal_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Modesto_City–County_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Moffett_Federal_Airfield'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Monterey_Regional_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Montgomery-Gibbs_Executive_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Scott_Valley_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Willits_Municipal_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Woodlake_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Fall_River_Mills_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Dinsmore_Airport_(California)'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Concord_Naval_Weapons_Station'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Amboy_Airfield'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Garberville_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Georgetown_Airport_(California)'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Lampson_Field'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Trinidad_State_Beach'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Trinity_Center_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Tulelake_Municipal_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Turlock_Municipal_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Ukiah_Municipal_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/University_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Brackett_Field'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Meadowlark_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Sacramento_Executive_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/San_Diego_International_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Santa_Ana_Army_Air_Base'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Santa_Cruz_Island_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Sutter_County_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Taft_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Tehachapi_Municipal_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Haigh_Field_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Lompoc_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Lone_Pine_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Lost_Hills_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Frazier_Lake_Airpark'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Hoopa_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Reedley_Municipal_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Rio_Vista_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Rio_Vista_Municipal_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Riverside_Municipal_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Tijuana_International_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Apple_Valley_Airport_(California)'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Elk_Hills-Buttonwillow_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Marine_Corps_Air_Station_Miramar'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Naval_Air_Station_North_Island'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Naval_Air_Weapons_Station_China_Lake'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Naval_Auxiliary_Landing_Field_San_Clemente_Island'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Naval_Outlying_Landing_Field_San_Nicolas_Island'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Nervino_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Perris_Valley_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Wasco_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Watsonville_Municipal_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Weaverville_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Weed_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Whiteman_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Cedarville_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Shelter_Cove_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Siskiyou_County_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Sonny_Bono_Salton_Sea_National_Wildlife_Refuge'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Blue_Canyon–Nyack_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Firebaugh_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Independence_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Kern_Valley_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': "http://dbpedia.org/resource/O'Sullivan_Army_Heliport"}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Oakdale_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Oceano_County_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Oceanside_Municipal_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Oroville_Municipal_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Palm_Springs_International_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Palo_Alto_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Rogers_Field'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Round_Valley_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Ruth_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Agua_Caliente_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Brown_Field_Municipal_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/San_Gabriel_Valley_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Van_Nuys_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/California_City_Municipal_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Chowchilla_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Cloverdale_Municipal_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Colusa_County_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Boonville_Airport_(California)'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Brawley_Municipal_Airport'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Bryant_Field_(airport)'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Pine_Mountain_Lake_Airport'}}]}}]},
#   {'id': '37',
#    'question': [{'language': 'en',
#      'string': 'What are the nicknames of San Francisco?'},
#     {'language': 'de', 'string': 'Was sind die Spitznamen von San Francisco?'},
#     {'language': 'ru', 'string': 'Какие прозвища у Сан-Франциско?'},
#     {'language': 'ru',
#      'string': 'Какие неофициальные названия есть у города Сан-Франциско?'},
#     {'language': 'ru', 'string': 'Какие прозвища есть у Сан-Франциско?'},
#     {'language': 'uk', 'string': 'Як ще називають Сан-Франциско?'},
#     {'language': 'be', 'string': 'Якія прозвiшча ў Сан-Францыска?'},
#     {'language': 'lt', 'string': 'Kokie yra San Francisko slapyvardžiai?'},
#     {'language': 'es',
#      'question': '¿Cuáles son los apodos de San Francisco?'}],
#    'query': {'sparql': 'PREFIX res: <http://dbpedia.org/resource/> PREFIX dbp: <http://dbpedia.org/property/> PREFIX foaf:<http://xmlns.com/foaf/0.1/> SELECT DISTINCT ?string WHERE { res:San_Francisco foaf:nick ?string }'},
#    'answers': [{'head': {'link': [], 'vars': ['string']},
#      'results': {'bindings': [{'string': {'type': 'literal',
#          'xml:lang': 'en',
#          'value': 'SeeList of nicknames for San Francisco'}}]}}]},
#   {'id': '32',
#    'question': [{'language': 'en',
#      'string': 'What is Angela Merkel’s birth name?'},
#     {'language': 'de', 'string': 'Wie ist Angela Merkels Geburtsname?'},
#     {'language': 'ru',
#      'string': 'Какое имя было дано Ангеле Меркель при рождении?'},
#     {'language': 'ru',
#      'string': 'Какое имя было у Ангелы Меркель при рождении?'},
#     {'language': 'ru', 'string': 'Как звали Ангелу Меркель при рождении?'},
#     {'language': 'uk',
#      'string': "Яке ім'я мала Ангела Меркель при народженні?"},
#     {'language': 'be',
#      'string': 'Якое імя было дадзена Ангеле Меркель пры нараджэнні?'},
#     {'language': 'lt',
#      'string': 'Koks vardas Angela Merkel buvo suteikta gimus?'},
#     {'language': 'es',
#      'question': '¿Cuál es el nombre de nacimiento de Angela Merkel?'}],
#    'query': {'sparql': 'PREFIX res: <http://dbpedia.org/resource/> PREFIX dbp: <http://dbpedia.org/property/> SELECT DISTINCT ?string WHERE { res:Angela_Merkel dbp:birthName ?string }'},
#    'answers': [{'head': {'link': [], 'vars': ['string']},
#      'results': {'bindings': [{'string': {'type': 'literal',
#          'xml:lang': 'en',
#          'value': 'Angela Dorothea Kasner'}}]}}]},
#   {'id': '31',
#    'question': [{'language': 'en', 'string': 'Who is the mayor of Berlin?'},
#     {'language': 'de', 'string': 'Wer ist Bürgermeister von Berlin?'},
#     {'language': 'ru', 'string': 'Кто мэр Берлина?'},
#     {'language': 'uk', 'string': 'Хто є мером Берліну?'},
#     {'language': 'be', 'string': 'Хто мэр Берліна?'},
#     {'language': 'lt', 'string': 'Kas yra Berlyno meras?'},
#     {'language': 'ba', 'string': 'Берлин ҡалаһының мэры кем?'},
#     {'language': 'es', 'question': '¿Quién es el alcalde de Berlín?'}],
#    'query': {'sparql': 'PREFIX dbo: <http://dbpedia.org/ontology/> PREFIX res: <http://dbpedia.org/resource/> SELECT DISTINCT ?uri WHERE { res:Berlin dbp:leader ?uri }'},
#    'answers': [{'head': {'link': [], 'vars': ['uri']},
#      'results': {'bindings': []}}]},
#   {'id': '29',
#    'question': [{'language': 'en',
#      'string': 'Which countries in the European Union adopted the Euro?'},
#     {'language': 'de',
#      'string': 'Welche Länder der Europäischen Union haben den Euro?'},
#     {'language': 'ru',
#      'string': 'Какие страны Европейского Союза стали использовать евро?'},
#     {'language': 'ru',
#      'string': 'Какие страны Европейского Союза приняли евро?'},
#     {'language': 'ru',
#      'string': 'Какие страны Европейского союза перешли на евро?'},
#     {'language': 'uk', 'string': 'Яки країни ЄС прийняли євро?'},
#     {'language': 'be',
#      'string': 'Якія краіны Еўрапейскага Саюза сталі выкарыстоўваць Еўра?'},
#     {'language': 'lt',
#      'string': 'Kurios Europos Sąjungos šalys pradėjo naudoti eurą?'},
#     {'language': 'es',
#      'question': '¿Qué países de la Unión Europea adoptaron el euro?'}],
#    'query': {'sparql': 'SELECT DISTINCT ?uri WHERE { ?uri a <http://dbpedia.org/ontology/Country> { ?uri <http://dbpedia.org/ontology/currency> <http://dbpedia.org/resource/Euro> } UNION { ?uri <http://dbpedia.org/property/currencyCode> "EUR"@en } }'},
#    'answers': [{'head': {'link': [], 'vars': ['uri']},
#      'results': {'bindings': [{'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Belgium'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Benelux'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Adélie_Land'}},
#        {'uri': {'type': 'uri',
#          'value': "http://dbpedia.org/resource/Luhansk_People's_Republic"}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Luxembourg'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/List_of_Cypriot_billionaires_by_net_worth'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Monaco'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Monastic_Republic_of_Mount_Athos'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Montenegro'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Mount_Athos'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Serbia_and_Montenegro'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Estonia'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/European_Single_Market'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/European_Union'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Basque_Country_(greater_region)'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Cyprus'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/List_of_Greeks_by_net_worth'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Nordic_Council'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Nordic_Council_of_Ministers'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Nordic_countries'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Andorra'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Germany'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Latvia'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Tromelin_Island'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Tyrol'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Kingdom_of_Wallachia'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/San_Marino'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Vatican_City'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Lithuania'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Gay_and_Lesbian_Kingdom_of_the_Coral_Sea_Islands'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/France'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/French_Fifth_Republic'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Frugal_Four'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Greece'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Republic_of_Ireland'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Third_Hellenic_Republic'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Third_Portuguese_Republic'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Îles_des_Saintes'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Austria'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Kingdom_of_the_Netherlands'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Kosovo'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Malta'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Netherlands'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Portugal'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Principality_of_Seborga'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Central_European_Free_Trade_Agreement'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Single_Euro_Payments_Area'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Slovakia'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Slovenia'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Spain'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Special_member_state_territories_and_the_European_Union'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Finland'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Kerguelen_Islands'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Organisation_of_Eastern_Caribbean_States'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Overseas_France'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Passports_in_Europe'}},
#        {'uri': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Twente'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Republic_of_Saugeais'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Akrotiri_and_Dhekelia'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Åland_Islands'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/SaarLorLux'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Saint_Barthélemy'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/French_Southern_and_Antarctic_Lands'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Italy'}}]}}]},
#   {'id': '23',
#    'question': [{'language': 'en',
#      'string': 'Which software has been published by Mean Hamster Software?'},
#     {'language': 'de',
#      'string': 'Welche Software wurde durch Mean Hamster Software veröffentlicht?'},
#     {'language': 'ru',
#      'string': 'Какое программно обеспечение было выпущено Mean Hamster Software?'},
#     {'language': 'ru',
#      'string': 'Какое программное обеспечение было выпущено компанией Mean Hamster Software?'},
#     {'language': 'ru',
#      'string': 'Какое программное обеспечение опубликовано компанией Mean Hamster Software?'},
#     {'language': 'uk',
#      'string': 'Яке програмне забезпечення опубліковало Mean Hamster Software?'},
#     {'language': 'lt',
#      'string': 'Kokią programinę įrangą išleido „Mean Hamster Software“?'},
#     {'language': 'es',
#      'question': '¿Qué software ha sido publicado por Mean Hamster Software?'}],
# ...
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Nansha_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Nanxi_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Peak_Walk'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Pierre_Laporte_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Pingsheng_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': "http://dbpedia.org/resource/Pont_d'Aquitaine"}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Porthill_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Puente_Colgante_(Manila)'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Puente_de_Occidente'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Randøy_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Waco_Suspension_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Waldo–Hancock_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Walter_Taylor_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Wheeling_Suspension_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Ram_Jhula'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Chain_Bridge_(Massachusetts)'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Chain_Bridge_(Nuremberg)'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Chesapeake_Bay_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Chirundu_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Dublin_Link'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/EG_LNG_Pipeline_Suspension_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Shantou_Bay_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Sidu_River_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Silver_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Simon_Kenton_Memorial_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Sotra_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/South_Tenth_Street_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/St._Johns_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Bertrand_Road_suspension_bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Beğendik_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Bidwell_Bar_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Black_Suspension_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Dalsfjord_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': "http://dbpedia.org/resource/Daly's_Bridge"}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Dazi_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Howrah_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Huangpu_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Humber_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Humen_Pearl_River_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Hålogaland_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Höga_Kusten_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/I-74_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Innoshima_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Kattel_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Nutty_Narrows_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Nærøysund_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Ogdensburg–Prescott_International_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Old_Donghe_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Osman_Gazi_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Osterøy_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Ostrovul_Mare_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Otowi_Suspension_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Ozimek_Suspension_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': "http://dbpedia.org/resource/Roebling's_Delaware_Aqueduct"}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Rombak_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Runyang_Yangtze_River_Bridge'}},
#        {'bridge': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Royal_Gorge_Bridge__Royal_Gorge_Bridge__1'}}]}}]},
#   {'id': '101',
#    'question': [{'language': 'en',
#      'string': 'How many companies were founded by the founder of Facebook?'},
#     {'language': 'de',
#      'string': 'Wie viele Unternehmen hat der Günder von Facebook gegründet?'},
#     {'language': 'ru',
#      'string': 'Как много компаний были основаны основателем Фейсбука?'},
#     {'language': 'uk',
#      'string': 'Скільки компаній засновав засновник Фейсбук?'},
#     {'language': 'lt', 'string': 'Kiek įmonių įkūrė „Facebook“ steigėjas?'},
#     {'language': 'be',
#      'string': 'Як шмат кампаній былі заснаваны заснавальнікам Фэйсбука?'},
#     {'language': 'lt', 'string': 'Kiek įmonių įkūrė „Facebook“ įkūrėjas?'},
#     {'language': 'es',
#      'question': '¿Cuántas empresas fueron fundadas por el fundador de Facebook?'}],
#    'query': {'sparql': 'SELECT (COUNT(DISTINCT ?x) AS ?c) WHERE { <http://dbpedia.org/resource/Facebook> <http://dbpedia.org/ontology/foundedBy> ?uri . ?x <http://dbpedia.org/ontology/foundedBy> ?uri }'},
#    'answers': [{'head': {'link': [], 'vars': ['c']},
#      'results': {'bindings': [{'c': {'type': 'typed-literal',
#          'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#          'value': '0'}}]}}]},
#   {'id': '14',
#    'question': [{'language': 'en',
#      'string': "Show me hiking trails in the Grand Canyon where there's no danger of flash floods."},
#     {'language': 'de',
#      'string': 'Zeige mir Wanderrouten im Grand Canyon, für die nicht die Gefahr von Sturzflut besteht.'},
#     {'language': 'ru',
#      'string': 'Покажите мне походные маршруты в Гарнд каньоне, где нет опасности паводков.'},
#     {'language': 'uk',
#      'string': 'Покажіть мені усі стежки в Гранд-Каньйоні, де немає небезпеки повені.'},
#     {'language': 'lt',
#      'string': 'Parodyk man pėsčiųjų takus Didžiajame kanjone, kur nėra staigių potvynių pavojaus.'},
#     {'language': 'be',
#      'string': 'Пакажыце мне паходныя маршруты ў Гарнд каньёне, дзе няма небяспекі паводак.'},
#     {'language': 'lt',
#      'string': 'Parodykite man pėsčiųjų takus Garnd kanjone, kur nėra potvynių pavojaus'},
#     {'language': 'lt',
#      'string': 'Parodykite man Garndo kanjono pėsčiųjų takus, kuriuose nėra potvynio pavojaus.'},
#     {'language': 'es',
#      'question': 'Muéstrame rutas de senderismo en el Gran Cañón donde no hay peligro de inundaciones repentinas.'}],
#    'query': {'sparql': 'SELECT DISTINCT ?uri WHERE { ?uri <http://dbpedia.org/property/trailheads> <http://dbpedia.org/resource/Grand_Canyon> FILTER NOT EXISTS { ?uri <http://dbpedia.org/property/hazards> <http://dbpedia.org/resource/Flash_flood> } }'},
#    'answers': [{'head': {'link': [], 'vars': ['uri']},
#      'results': {'bindings': [{'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Bright_Angel_Trail'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/North_Kaibab_Trail'}}]}}]},
#   {'id': '87',
#    'question': [{'language': 'en', 'string': 'Which book has the most pages?'},
#     {'language': 'de', 'string': 'Welches Buch hat die meisten Seiten?'},
#     {'language': 'ru', 'string': 'В какой книге больше всего страниц?'},
#     {'language': 'uk',
#      'string': 'Яка книжка має найбільшу кількість сторінок?'},
#     {'language': 'lt', 'string': 'Kuri knyga turi daugiausiai puslapių?'},
#     {'language': 'be', 'string': 'У якой кнізе больш за ўсё старонак?'},
#     {'language': 'ba', 'string': 'Барыһы китап биттәрендә күберәк ниндәй?'},
#     {'language': 'es', 'question': '¿Qué libro tiene más páginas?'}],
#    'query': {'sparql': 'PREFIX dbo: <http://dbpedia.org/ontology/> PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> SELECT DISTINCT ?uri WHERE { ?uri rdf:type dbo:Book ; dbo:numberOfPages ?n } ORDER BY DESC(?n) OFFSET 0 LIMIT 1'},
#    'answers': [{'head': {'link': [], 'vars': ['uri']},
#      'results': {'bindings': [{'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/The_Tolkien_Reader'}}]}}]},
#   {'id': '148',
#    'question': [{'language': 'en',
#      'string': 'What is the largest state in the United States?'},
#     {'language': 'de', 'string': 'Welche ist die größte Stadt der USA?'},
#     {'language': 'ru', 'string': 'Какой из штатов США - наибольший?'},
#     {'language': 'uk', 'string': 'Який найбільший штат у Сполучених Штатах?'},
#     {'language': 'lt', 'string': 'Kokia didžiausia JAV valstija?'},
#     {'language': 'be', 'string': 'Які з штатаў ЗША - найбольшы?'},
#     {'language': 'lt', 'string': 'Kuri iš JAV valstijų yra didžiausia?'},
#     {'language': 'ba', 'string': 'Аҡш штаттары араһында ниндәй - оло?'},
#     {'language': 'es',
#      'question': '¿Cuál es el estado más grande de los Estados Unidos?'}],
#    'query': {'sparql': 'PREFIX dbo: <http://dbpedia.org/ontology/> PREFIX dct: <http://purl.org/dc/terms/> PREFIX dbc: <http://dbpedia.org/resource/Category:> PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> SELECT ?uri WHERE { ?uri dct:subject dbc:States_of_the_United_States ; rdf:type dbo:AdministrativeRegion ; dbo:areaTotal ?area } ORDER BY DESC(?area) OFFSET 0 LIMIT 1'},
#    'answers': [{'head': {'link': [], 'vars': ['uri']},
#      'results': {'bindings': [{'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Alaska'}}]}}]},
#   {'id': '43',
#    'question': [{'language': 'en',
#      'string': 'Give me the websites of companies with more than 500000 employees.'},
#     {'language': 'de',
#      'string': 'Liste die Internetseiten von Unternehmen mit mehr als 500000 Mitarbeitern auf.'},
#     {'language': 'ru',
#      'string': 'Покажите мне сайты компаний, у которых более 500000 работников.'},
#     {'language': 'uk',
#      'string': 'Назвіть мені сайти компаній з більш ніж 500000 працівниками.'},
#     {'language': 'lt',
#      'string': 'Pasakyk man kompanijų svetaines su daugiau nei 500.000 darbuotojų.'},
#     {'language': 'lt',
#      'string': 'Parodykite man įmonių, kuriose dirba daugiau nei 500 000 darbuotojų, svetaines'},
#     {'language': 'es',
#      'question': 'Dame los sitios web de empresas con más de 500000 empleados.'}],
#    'query': {'sparql': 'PREFIX foaf: <http://xmlns.com/foaf/0.1/> PREFIX dbo: <http://dbpedia.org/ontology/> PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> SELECT distinct ?web WHERE { ?sub dbo:numberOfEmployees ?obj . ?sub foaf:homepage ?web FILTER( xsd:integer(?obj) > 500000 ) . }'},
#    'answers': [{'head': {'link': [], 'vars': ['web']},
#      'results': {'bindings': [{'web': {'type': 'uri',
#          'value': 'http://www.onoff.se'}},
#        {'web': {'type': 'uri', 'value': 'http://www.tesco.com'}},
#        {'web': {'type': 'uri', 'value': 'https://www.compass-group.com'}},
#        {'web': {'type': 'uri', 'value': 'http://www.bundespost.de/'}},
#        {'web': {'type': 'uri', 'value': 'https://www.dpdhl.com/'}},
#        {'web': {'type': 'uri', 'value': 'http://lindenlab.com/'}},
#        {'web': {'type': 'uri', 'value': 'https://www.usps.com'}},
#        {'web': {'type': 'uri', 'value': 'http://www.marykay.com/'}},
#        {'web': {'type': 'uri', 'value': 'https://mod.gov.in'}},
#        {'web': {'type': 'uri', 'value': 'http://mod.gov.pk'}},
#        {'web': {'type': 'uri', 'value': 'http://www.moe.gov.my/'}},
#        {'web': {'type': 'uri', 'value': 'https://cso.moi.gov.eg/'}},
#        {'web': {'type': 'uri', 'value': 'http://en.mvd.ru'}},
#        {'web': {'type': 'uri', 'value': 'http://www.mps.gov.cn'}},
#        {'web': {'type': 'uri', 'value': 'http://www.indianrailways.gov.in'}},
#        {'web': {'type': 'uri', 'value': 'http://www.sahara.in/'}},
#        {'web': {'type': 'uri',
#          'value': 'http://www.sgcc.com.cn/ywlm/index.shtml'}},
#        {'web': {'type': 'uri', 'value': 'http://www.tata.com/'}},
#        {'web': {'type': 'uri', 'value': 'http://www.indianrail.gov.in/'}},
#        {'web': {'type': 'uri', 'value': 'http://indianrailways.gov.in/'}},
#        {'web': {'type': 'uri', 'value': 'http://www.foxconn.com'}},
#        {'web': {'type': 'uri', 'value': 'https://www.ritek.com/'}},
#        {'web': {'type': 'uri', 'value': 'http://tocaboca.com/'}},
#        {'web': {'type': 'uri', 'value': 'http://www.petrochina.com.cn/ptr/'}},
#        {'web': {'type': 'uri',
#          'value': 'http://www.sinopecgroup.com/group/en/'}},
#        {'web': {'type': 'uri', 'value': 'http://medu.ir'}},
#        {'web': {'type': 'uri',
#          'value': 'http://www2.datasus.gov.br/DATASUS/index.php'}},
#        {'web': {'type': 'uri', 'value': 'http://www.errt.org/'}},
#        {'web': {'type': 'uri', 'value': 'http://inspirebrands.com'}},
#        {'web': {'type': 'uri', 'value': 'https://eng.rzd.ru/en/9446/'}}]}}]},
#   {'id': '179',
#    'question': [{'language': 'en',
#      'string': 'What were the names of the three ships by Columbus?'},
#     {'language': 'de', 'string': 'Wie hieße die drei Schiffe von Kolumbus?'},
#     {'language': 'ru', 'string': 'Как назывались три корабля Колумба?'},
#     {'language': 'uk', 'string': 'Як називалися три кораблі Колумба?'},
#     {'language': 'lt',
#      'string': 'Kokios buvo trys Kolumbo laivų pavadinimai?'},
#     {'language': 'lt', 'string': 'Kaip vadinosi trys Kolumbo laivai?'},
#     {'language': 'ba', 'string': 'Колумб өс карабы нисек аталған?'},
#     {'language': 'es',
#      'question': '¿Cuáles eran los nombres de los tres barcos de Colón?'}],
#    'query': {'sparql': 'PREFIX dbo: <http://dbpedia.org/ontology/> PREFIX dct: <http://purl.org/dc/terms/> PREFIX dbc: <http://dbpedia.org/resource/Category:> PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> SELECT ?uri WHERE { ?uri rdf:type dbo:Ship ; dct:subject dbc:Christopher_Columbus ; dct:subject dbc:Exploration_ships }'},
#    'answers': [{'head': {'link': [], 'vars': ['uri']},
#      'results': {'bindings': [{'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Niña'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Santa_María_(ship)'}},
#        {'uri': {'type': 'uri',
#          'value': 'http://dbpedia.org/resource/Pinta_(ship)'}}]}}]}]}

# %% [markdown]
# Everything seem to be correct, let's check the stats

# %%
def show_stats(data):
    lang_dict = dict()
    for q in data['questions']:
        for lang in q['question']:
            if lang['language'] not in lang_dict.keys():
                lang_dict[lang['language']] = [lang]
            else:
                lang_dict[lang['language']].append(lang)
                
    for k, v in lang_dict.items():
        print(k, len(v))

# %%
show_stats(test_dbpedia)
# Out:
# en 150
# de 176
# ru 348
# uk 176
# lt 186
# be 155
# ba 117
# es 150
# hy 20
# fr 26

# %% [markdown]
# Now we can translate all the data

# %%
train_dbpedia = translate_questions(train_dbpedia)

# %%
test_wikidata = translate_questions(test_wikidata)

# %%
train_wikidata = translate_questions(train_wikidata)

# %% [markdown]
# Let's check all the stats before saving

# %%
show_stats(train_dbpedia)
# Out:
# en 408
# de 543
# ru 1203
# lt 468
# uk 447
# fr 260
# es 408
# be 441
# ba 284
# hy 80

# %%
show_stats(test_wikidata)
# Out:
# en 136
# de 159
# ru 318
# uk 160
# lt 166
# be 141
# ba 107
# es 136
# hy 19
# fr 25

# %%
show_stats(train_wikidata)
# Out:
# en 371
# de 497
# ru 1095
# lt 426
# uk 407
# fr 251
# es 371
# be 403
# ba 260
# hy 71

# %% [markdown]
# Now we are ready to save the new version

# %%
def save_json(filename, data):
    """save json"""
    with open(filename, 'w', encoding="utf8") as f:
        json.dump(data, f, indent=4, ensure_ascii=False)

# %%
save_json("../data/qald_9_plus_test_dbpedia.json", test_dbpedia)

# %%
save_json("../data/qald_9_plus_train_dbpedia.json", train_dbpedia)

# %%
save_json("../data/qald_9_plus_test_wikidata.json", test_wikidata)

# %%
save_json("../data/qald_9_plus_train_wikidata.json", train_wikidata)
